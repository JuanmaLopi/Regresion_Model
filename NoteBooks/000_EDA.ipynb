# %%
import pandas as pd

# %%
# Cargar los archivos CSV
data_2015 = pd.read_csv('../data/2015.csv')
data_2016 = pd.read_csv('../data/2016.csv')
data_2017 = pd.read_csv('../data/2017.csv')
data_2018 = pd.read_csv('../data/2018.csv')
data_2019 = pd.read_csv('../data/2019.csv')

# %%
print("Columnas en 2015.csv:", data_2015.columns)
print("Columnas en 2016.csv:", data_2016.columns)
print("Columnas en 2017.csv:", data_2017.columns)
print("Columnas en 2018.csv:", data_2018.columns)
print("Columnas en 2019.csv:", data_2019.columns)
# Out:
# Columnas en 2015.csv: Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')
# Columnas en 2016.csv: Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Lower Confidence Interval', 'Upper Confidence Interval',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')
# Columnas en 2017.csv: Index(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
#        'Health..Life.Expectancy.', 'Freedom', 'Generosity',
#        'Trust..Government.Corruption.', 'Dystopia.Residual'],
#       dtype='object')
# ...

# %%
data_2015 = data_2015.drop(columns={
    #'Country',
    'Region',
    'Happiness Rank',
    'Standard Error',
    'Dystopia Residual'
})

data_2015 = data_2015.rename(columns={
    'Family': 'Social support'
})

data_2015 = data_2015.round(3)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Calcular la matriz de correlación de las variables numericas
correlation_matrix = data_2015.drop(columns=['Country']).corr()

# Crear un mapa de calor de la matriz de correlación
plt.figure(figsize=(10, 8))  
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0, linewidths=0.5)

# Personalizar el gráfico
plt.title('Mapa de calor de correlación')
plt.show()

# %%
data_2016 = data_2016.drop(columns={
    #'Country',
    'Region',
    'Happiness Rank',
    'Dystopia Residual',
    'Lower Confidence Interval',
    'Upper Confidence Interval'
})

data_2016 = data_2016.rename(columns={
    'Family': 'Social support'
})

data_2016 = data_2016.round(3)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Calcular la matriz de correlación de las variables numericas
correlation_matrix = data_2016.drop(columns=['Country']).corr()

# Crear un mapa de calor de la matriz de correlación
plt.figure(figsize=(10, 8))  # Ajusta el tamaño de la figura
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0, linewidths=0.5)

# Personalizar el gráfico
plt.title('Mapa de calor de correlación')
plt.show()

# %%
data_2017.columns = data_2017.columns.str.replace('"', '', regex=False).str.replace("'", "", regex=False)


data_2017 = data_2017.drop(columns={
    #'Country',
    'Happiness.Rank',
    'Whisker.high',
    'Whisker.low',
    'Dystopia.Residual'

})

data_2017 = data_2017.rename(columns={
    'Happiness.Score': 'Happiness Score',
    'Economy..GDP.per.Capita.': 'Economy (GDP per Capita)',
    'Family': 'Social support',
    'Health..Life.Expectancy.': 'Health (Life Expectancy)',
    'Trust..Government.Corruption.': 'Trust (Government Corruption)'
})

data_2017 = data_2017.round(3)

# %%
columnas = list(data_2017.columns)
columnas[5], columnas[6] = columnas[6], columnas[5] 
data_2017 = data_2017[columnas]
print(data_2017.columns)
# Out:
# Index(['Country', 'Happiness Score', 'Economy (GDP per Capita)',
#        'Social support', 'Health (Life Expectancy)', 'Freedom',
#        'Trust (Government Corruption)', 'Generosity'],
#       dtype='object')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Calcular la matriz de correlación de las variables númericas
correlation_matrix = data_2017.drop(columns=['Country']).corr()

# Crear un mapa de calor de la matriz de correlación
plt.figure(figsize=(10, 8))  # Ajusta el tamaño de la figura
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0, linewidths=0.5)

# Personalizar el gráfico
plt.title('Mapa de calor de correlación')
plt.show()

# %%
data_2018 = data_2018.drop(columns={
    'Overall rank',
    #'Country or region'
})

data_2018 = data_2018.rename(columns={
    'Score': 'Happiness Score',
    'GDP per capita': 'Economy (GDP per Capita)',
    'Healthy life expectancy': 'Health (Life Expectancy)',
    'Freedom to make life choices': 'Freedom',
    'Perceptions of corruption': 'Trust (Government Corruption)', 
    'Country or region' : 'Country'
})

data_2018 = data_2018.round(3)

# %%
columnas = list(data_2018.columns)
columnas[6], columnas[7] = columnas[7], columnas[6] 
data_2018 = data_2018[columnas]
print(data_2018.columns)
# Out:
# Index(['Country or region', 'Happiness Score', 'Economy (GDP per Capita)',
#        'Social support', 'Health (Life Expectancy)', 'Freedom',
#        'Trust (Government Corruption)', 'Generosity'],
#       dtype='object')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Calcular la matriz de correlación de las variables númericas
correlation_matrix = data_2018.drop(columns=['Country']).corr()

# Crear un mapa de calor de la matriz de correlación
plt.figure(figsize=(10, 8))  # Ajusta el tamaño de la figura
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0, linewidths=0.5)

# Personalizar el gráfico
plt.title('Mapa de calor de correlación')
plt.show()

# %%
data_2019 = data_2019.drop(columns={
    'Overall rank',
    #'Country or region'
})

data_2019 = data_2019.rename(columns={
    'Score': 'Happiness Score',
    'GDP per capita': 'Economy (GDP per Capita)',
    'Healthy life expectancy': 'Health (Life Expectancy)',
    'Freedom to make life choices': 'Freedom',
    'Perceptions of corruption': 'Trust (Government Corruption)', 
    'Country or region' : 'Country'
})

data_2019 = data_2019.round(3)

# %%
columnas = list(data_2019.columns)
columnas[7], columnas[6] = columnas[6], columnas[7] 
data_2019 = data_2019[columnas]
print(data_2019.columns)
# Out:
# Index(['Country', 'Happiness Score', 'Economy (GDP per Capita)',
#        'Social support', 'Health (Life Expectancy)', 'Freedom',
#        'Trust (Government Corruption)', 'Generosity'],
#       dtype='object')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Calcular la matriz de correlación dfe las variables númericas
correlation_matrix = data_2019.drop(columns=['Country']).corr()

# Crear un mapa de calor de la matriz de correlación
plt.figure(figsize=(10, 8))  # Ajusta el tamaño de la figura
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0, linewidths=0.5)

# Personalizar el gráfico
plt.title('Mapa de calor de correlación')
plt.show()

# %%
data_2015['Year'] = 2015
data_2016['Year'] = 2016
data_2017['Year'] = 2017
data_2018['Year'] = 2018
data_2019['Year'] = 2019

# %%
print("Columnas en 2015.csv:", data_2015.columns)
print("Columnas en 2016.csv:", data_2016.columns)
print("Columnas en 2017.csv:", data_2017.columns)
print("Columnas en 2018.csv:", data_2018.columns)
print("Columnas en 2019.csv:", data_2019.columns)
# Out:
# Columnas en 2015.csv: Index(['Country', 'Happiness Score', 'Economy (GDP per Capita)',
#        'Social support', 'Health (Life Expectancy)', 'Freedom',
#        'Trust (Government Corruption)', 'Generosity', 'Year'],
#       dtype='object')
# Columnas en 2016.csv: Index(['Country', 'Happiness Score', 'Economy (GDP per Capita)',
#        'Social support', 'Health (Life Expectancy)', 'Freedom',
#        'Trust (Government Corruption)', 'Generosity', 'Year'],
#       dtype='object')
# Columnas en 2017.csv: Index(['Country', 'Happiness Score', 'Economy (GDP per Capita)',
#        'Social support', 'Health (Life Expectancy)', 'Freedom',
#        'Trust (Government Corruption)', 'Generosity', 'Year'],
#       dtype='object')
# Columnas en 2018.csv: Index(['Country', 'Happiness Score', 'Economy (GDP per Capita)',
#        'Social support', 'Health (Life Expectancy)', 'Freedom',
#        'Trust (Government Corruption)', 'Generosity', 'Year'],
#       dtype='object')
# ...

# %%
import pandas as pd

# Configure pandas to display more rows and columns
pd.set_option('display.max_rows', 100)  # Show up to 100 rows
pd.set_option('display.max_columns', None)  # Show all columns without truncation
pd.set_option('display.width', None)  # Automatically adjust display width to fit the content

# Display the first 20 rows in a tabular format
data_2015.head(2)
# Out:
#        Country  Happiness Score  Economy (GDP per Capita)  Social support  \
# 0  Switzerland            7.587                     1.397           1.350
# 1      Iceland            7.561                     1.302           1.402
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.941    0.666                          0.420
# 1                     0.948    0.629                          0.141
#
#    Generosity  Year
# 0       0.297  2015
# 1       0.436  2015

# %%
import pandas as pd

# Configure pandas to display more rows and columns
pd.set_option('display.max_rows', 100)  # Show up to 100 rows
pd.set_option('display.max_columns', None)  # Show all columns without truncation
pd.set_option('display.width', None)  # Automatically adjust display width to fit the content

# Display the first 20 rows in a tabular format
data_2016.head(2)
# Out:
#        Country  Happiness Score  Economy (GDP per Capita)  Social support  \
# 0      Denmark            7.526                     1.442           1.164
# 1  Switzerland            7.509                     1.527           1.145
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.795    0.579                          0.445
# 1                     0.863    0.586                          0.412
#
#    Generosity  Year
# 0       0.362  2016
# 1       0.281  2016

# %%
import pandas as pd

# Configure pandas to display more rows and columns
pd.set_option('display.max_rows', 100)  # Show up to 100 rows
pd.set_option('display.max_columns', None)  # Show all columns without truncation
pd.set_option('display.width', None)  # Automatically adjust display width to fit the content

# Display the first 20 rows in a tabular format
data_2017.head(2)
# Out:
#    Country  Happiness Score  Economy (GDP per Capita)  Social support  \
# 0   Norway            7.537                     1.616           1.534
# 1  Denmark            7.522                     1.482           1.551
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.797    0.635                          0.316
# 1                     0.793    0.626                          0.401
#
#    Generosity  Year
# 0       0.362  2017
# 1       0.355  2017

# %%
import pandas as pd

# Configure pandas to display more rows and columns
pd.set_option('display.max_rows', 100)  # Show up to 100 rows
pd.set_option('display.max_columns', None)  # Show all columns without truncation
pd.set_option('display.width', None)  # Automatically adjust display width to fit the content

# Display the first 20 rows in a tabular format
data_2018.head(2)
# Out:
#    Country  Happiness Score  Economy (GDP per Capita)  Social support  \
# 0  Finland            7.632                     1.305           1.592
# 1   Norway            7.594                     1.456           1.582
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.874    0.681                          0.393
# 1                     0.861    0.686                          0.340
#
#    Generosity  Year
# 0       0.202  2018
# 1       0.286  2018

# %%
import pandas as pd

# Configure pandas to display more rows and columns
pd.set_option('display.max_rows', 100)  # Show up to 100 rows
pd.set_option('display.max_columns', None)  # Show all columns without truncation
pd.set_option('display.width', None)  # Automatically adjust display width to fit the content

# Display the first 20 rows in a tabular format
data_2019.head(2)
# Out:
#    Country  Happiness Score  Economy (GDP per Capita)  Social support  \
# 0  Finland            7.769                     1.340           1.587
# 1  Denmark            7.600                     1.383           1.573
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.986    0.596                          0.393
# 1                     0.996    0.592                          0.410
#
#    Generosity  Year
# 0       0.153  2019
# 1       0.252  2019

# %%
# Combinar los archivos
data_to_model = pd.concat([data_2015, data_2016, data_2017, data_2018, data_2019], ignore_index=True)
data_to_model = data_to_model.dropna()

# Guardar el archivo combinado en un nuevo CSV
data_to_model.to_csv('../data/Model_Data.csv', index=False)

print(f"Archivos combinados exitosamente en 'Model_Data.csv' con {data_to_model.shape[0]} filas y {data_to_model.shape[1]} columnas")
# Out:
# Archivos combinados exitosamente en 'Model_Data.csv' con 781 filas y 9 columnas
